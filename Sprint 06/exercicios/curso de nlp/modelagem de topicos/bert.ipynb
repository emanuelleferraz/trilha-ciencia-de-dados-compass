# %% [markdown]
# # Modelagem de Tópicos - BERT

# %%
from zipfile import ZipFile

import nltk
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# !pip install BERTopic
# !pip install sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 47.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from sentence_transformers import SentenceTransformer

# %%
zip = ZipFile("documentos.zip")
zip.extractall()

# %%
import glob
dados = []
dir = "/content/documentos/"
for arquivo in glob.iglob(dir + '*.txt', recursive=False):
  meuarquivo = open(arquivo, "r", encoding="utf8")
  content = meuarquivo.read()
  dados.append(content)
  meuarquivo.close()

# %%
len(dados)
# Out:
# 22

# %%
dados[3]
# Out:
# 'Informática médica\nOrigem: Wikipédia, a enciclopédia livre.\n\nEsta página cita fontes, mas estas não cobrem todo o conteúdo. Ajude a inserir referências. Conteúdo não verificável poderá ser removido.—Encontre fontes: Google (notícias, livros e acadêmico) (Abril de 2016)\nInformática médica, segundo Blois & Shortliffe, é o campo de estudo relacionado à vasta gama de recursos que podem ser aplicados no gerenciamento e utilização da informação biomédica, incluindo a computação médica e o próprio estudo da natureza da informação médica. É um campo multidisciplinar.[1]\n\nSe biologia significa literalmente \'o estudo da vida\', e patologia significa \'o estudo da doença\', então informática médica significa o \'estudo da informação na prestação de cuidados de saúde\'. É o estudo racional da forma como pensamos os pacientes e da forma como são definidos, selecionados e evoluem os tratamentos. É o estudo da forma como o conhecimento médico é criado, moldado, partilhado e aplicado. Em últ
# ...

# %% [markdown]
# # Processamento dos Dados

# %% [markdown]
# ## Tokenização

# %%
sentencas = []
for item in dados:
  for t in sent_tokenize(item):
    sentencas.append(t)

# %%
len(sentencas)
# Out:
# 1504

# %%
sentencas[300]
# Out:
# '[13] O trabalho matemático de James Clerk Maxwell durante a década de 1850 tinha apresentado a possibilidade de existirem ondas de rádio, porém, Heinrich Hertz foi o primeiro a demonstrar a sua existência em 1888.'

# %% [markdown]
# # Criação e Treinamento do Modelo

# %%
modelo = BERTopic(language="portuguese", verbose=True, embedding_model="xlm-r-bert-base-nli-stsb-mean-tokens",
                  top_n_words=15, min_topic_size=10, nr_topics=20,
                  vectorizer_model=CountVectorizer(ngram_range=(1,3),
                   stop_words=stopwords.words("portuguese"), min_df=10))

# %% [markdown]
# Hiperparâmetros:
#   - top_n_words: quantas palavras terá cada tópico
#   - n_gram_range: N_gram (intervalo)
#   - min_topic_size: tamanho mínimo que um tópico deve ter para ser criado
#   - nr_topics: reduz o número de tópico iniciais para este número
#   - vetorizer_model: vetorização para o modelo
#   - embedding_model: setenças/similaridades

# %%
topicos, probabilidades = modelo.fit_transform(sentencas)
# Out:
# 2025-01-31 22:31:54,210 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.05k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/722 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/518 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/47 [00:00<?, ?it/s]
# 2025-01-31 22:35:26,282 - BERTopic - Embedding - Completed ✓
# ...

# %%
frequencia = modelo.get_topic_info()
frequencia.head(10)
# Out:
#    Topic  Count                                  Name  \
# 0     -1    394  -1_grande_além_estruturas_engenharia
# 1      0    213  0_engenharia_controle_forma_diversos
# 2      1    171      1_maior_cada_estruturas_formação
# 3      2    163   2_sobre_ciência_desenvolvimento_ver
# 4      3    146      3_sistema_sendo_principal_outras
# 5      4     75    4_engenharia_formação_ver_sistemas
# 6      5     57         5_dados_ainda_área_tecnologia
# 7      6     55         6_área_outras_grande_técnicas
# 8      7     25         7_controle_outras_muitos_além
# 9      8     25  8_sistemas_engenharia_ciência_grande
#
#                                       Representation  \
# 0  [grande, além, estruturas, engenharia, ainda, ...
# 1  [engenharia, controle, forma, diversos, técnic...
# 2  [maior, cada, estruturas, formação, pode, sobr...
# 3  [sobre, ciência, desenvolvimento, ver, tecnolo...
# 4  [sistema, sendo, principal, outras, pode, exem...
# ...

# %%
modelo.get_topic(7)
# Out:
# [('controle', 0.1363759611603613),
#  ('outras', 0.11201100306957947),
#  ('muitos', 0.09571727318527429),
#  ('além', 0.09570324258988364),
#  ('área', 0.06635673323329117),
#  ('outros', 0.06145188840932903),
#  ('geralmente', 0.055112143508167455),
#  ('outro', 0.05240926752837235),
#  ('desde', 0.047858636592637144),
#  ('cada', 0.041771794374391207),
#  ('ciência', 0.04104336219724384),
#  ('assim', 0.04034325566611143),
#  ('diversos', 0.03966968815564311),
#  ('tecnologia', 0.038395794278634605),
#  ('exemplo', 0.03557681866297842)]

# %%
modelo.visualize_barchart(n_words=15,top_n_topics=20 )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
modelo.visualize_barchart(n_words=10,topics=[0,3] )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
modelo.visualize_hierarchy(top_n_topics=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
modelo.visualize_heatmap(n_clusters=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
